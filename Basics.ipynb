# %% [markdown]
# ![image.png](attachment:3f825699-201e-468a-a968-640ae0cb87b7.png)![image.png](attachment:2a9839d0-3bbd-4421-b627-b3a80ac8cff6.png)

# %% [markdown]
# # Basics of Data Science for Financial Markets

# %%
import pandas as pd
import numpy as np
import quantstats as qt

# %%
TSLA = qt.utils.download_returns('TSLA')
TSLA = TSLA.loc['2023-03-01':'2023-03-12']

# %%
TSLA.head()
# Out:
# Date
# 2023-03-01 00:00:00-05:00   -0.014292
# 2023-03-02 00:00:00-05:00   -0.058539
# 2023-03-03 00:00:00-05:00    0.036092
# 2023-03-06 00:00:00-05:00   -0.020122
# 2023-03-07 00:00:00-05:00   -0.031474
# Name: Close, dtype: float64

# %%
TSLA.index = TSLA.index.tz_convert(None)

# %%
TSLA.index
# Out:
# DatetimeIndex(['2023-03-01 05:00:00', '2023-03-02 05:00:00',
#                '2023-03-03 05:00:00', '2023-03-06 05:00:00',
#                '2023-03-07 05:00:00', '2023-03-08 05:00:00',
#                '2023-03-09 05:00:00', '2023-03-10 05:00:00'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
qt.plots.daily_returns(TSLA)
